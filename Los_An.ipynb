# %%
import os
HOCKEY_PATH = os.path.join("datasets", "hockey")
os.path.join("datasets", "hockey", "hockey_2019_01_21.csv")
# Out:
# 'datasets\\hockey\\hockey_2019_01_21.csv'

# %%
import pandas as pd

def load_hockey_data(hockey_path=HOCKEY_PATH):
    csv_path = os.path.join("datasets", "hockey", "hockey_2019_01_21.csv")
    return pd.read_csv(csv_path)

# %%
hockey = load_hockey_data()
hockey.head()
# Out:
#      DataTime      Hosts    Guests  1PHosts  2PHosts  3PHosts  OverHosts  \
# 0  2018-10-04    Торонто  Монреаль        1        1        0          1
# 1  2018-10-04  Вашингтон    Бостон        2        4        1          0
# 2  2018-10-04   Ванкувер   Калгари        1        0        4          0
# 3  2018-10-04   Сан-Хосе   Анахайм        1        1        0          0
# 4  2018-10-05    Баффало    Бостон        0        0        0          0
#
#    CountHosts  1PGuests  2PGuests  3PGuests  OverGuests  CountGuests
# 0           3         1         1         0           0            2
# 1           7         0         0         0           0            0
# 2           5         0         0         2           0            2
# 3           2         1         1         3           0            5
# 4           0         2         1         1           0            4

# %%
hockey_hosts_la = hockey.where(hockey["Hosts"] == "Лос-Анджелес").dropna()
hockey_hosts_la
# Out:
#        DataTime         Hosts       Guests  1PHosts  2PHosts  3PHosts  \
# 15   2018-10-06  Лос-Анджелес     Сан-Хосе      1.0      1.0      0.0
# 30   2018-10-08  Лос-Анджелес      Детройт      0.0      2.0      2.0
# 96   2018-10-19  Лос-Анджелес    Айлендерс      1.0      0.0      1.0
# 103  2018-10-20  Лос-Анджелес      Баффало      0.0      0.0      1.0
# 158  2018-10-28  Лос-Анджелес    Рейнджерс      0.0      2.0      2.0
# 189  2018-11-02  Лос-Анджелес  Филадельфия      0.0      2.0      0.0
# 205  2018-11-04  Лос-Анджелес     Коламбус      1.0      1.0      2.0
# 221  2018-11-07  Лос-Анджелес      Анахайм      2.0      1.0      1.0
# 234  2018-11-09  Лос-Анджелес    Миннесота      1.0      0.0      0.0
# 251  2018-11-11  Лос-Анджелес      Калгари      0.0      0.0      0.0
# 270  2018-11-14  Лос-Анджелес      Торонто      1.0      0.0      0.0
# 330  2018-11-22  Лос-Анджелес     Колорадо      1.0      0.0      2.0
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_encoder = OrdinalEncoder()
hockey_cat_encoded = ordinal_encoder.fit_transform(hockey_hosts_la.Guests)

hockey_cat_encoded[:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-715d177e6ceb> in <module>
#       1 ordinal_encoder = OrdinalEncoder()
# ----> 2 hockey_cat_encoded = ordinal_encoder.fit_transform(hockey_hosts_la.Guests)
#       3
#       4 hockey_cat_encoded[:10]
#
# c:\users\katirkin\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     460         if y is None:
#     461             # fit method of arity 1 (unsupervised transformation)
# --> 462             return self.fit(X, **fit_params).transform(X)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
#
# c:\users\katirkin\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
# ...

# %%
try:
    from sklearn.preprocessing import OrdinalEncoder # just to raise an ImportError if Scikit-Learn < 0.20
    from sklearn.preprocessing import OneHotEncoder
except ImportError:
    from future_encoders import OneHotEncoder # Scikit-Learn < 0.20

cat_encoder = OneHotEncoder()
hockey_cat_1hot = cat_encoder.fit_transform(hockey_hosts_la.Guests.reshape(-1, 1))
hockey_cat_1hot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9e752b9e01e7> in <module>
#       6
#       7 cat_encoder = OneHotEncoder()
# ----> 8 hockey_cat_1hot = cat_encoder.fit_transform(hockey_hosts_la.Guests.reshape(-1, 1))
#       9 hockey_cat_1hot
#
# c:\users\katirkin\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'reshape'
